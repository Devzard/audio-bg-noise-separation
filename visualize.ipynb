# %%
import utilities

# %%
source = "./data/sample1/source.wav"
noise = "./data/sample1/noise.wav"
overlayed = "./data/sample1/overlayed.wav"

# %% [markdown]
# ## Source

# %%
src_samples, src_sampling_rate = utilities.load_audio(source)
src_audio_len = len(src_samples)/src_sampling_rate
print("Time Domain Representation")
utilities.plot_waveshow_td_representation(src_samples, src_sampling_rate)

src_freq_data, src_mag = utilities.perform_fft(src_samples, src_sampling_rate)
print("Frequency Domain Representation")
utilities.plot_fd_representation(src_freq_data, src_mag)

src_specgram = utilities.spectrogram(src_samples, src_sampling_rate, max_freq=max(src_freq_data))
print("Spectrogram")
utilities.plot_specgram(src_specgram, src_audio_len, src_sampling_rate)
# Out:
# /home/debashish/miniconda3/envs/mini-project/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Time Domain Representation
# Frequency Domain Representation
# Spectrogram

# %% [markdown]
# ## Noise

# %%
noise_samples, noise_sampling_rate = utilities.load_audio(noise)
noise_audio_len = len(noise_samples)/noise_sampling_rate
print("Time Domain Representation")
utilities.plot_waveshow_td_representation(noise_samples, noise_sampling_rate)

noise_freq_data, noise_mag = utilities.perform_fft(noise_samples, noise_sampling_rate)
print("Frequency Domain Representation")
utilities.plot_fd_representation(noise_freq_data, noise_mag)

nosie_specgram = utilities.spectrogram(noise_samples, noise_sampling_rate, max_freq=max(noise_freq_data))
print("Spectrogram")
utilities.plot_specgram(nosie_specgram, noise_audio_len, noise_sampling_rate)
# Out:
# /home/debashish/miniconda3/envs/mini-project/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Time Domain Representation
# Frequency Domain Representation
# Spectrogram

# %% [markdown]
# ## Overlayed

# %%
overlayed_samples, overlayed_sampling_rate = utilities.load_audio(overlayed)
overlayed_audio_len = len(overlayed_samples)/overlayed_sampling_rate
print("Time Domain Representation")
utilities.plot_waveshow_td_representation(overlayed_samples, overlayed_sampling_rate)

overlayed_freq_data, overlayed_mag = utilities.perform_fft(overlayed_samples, overlayed_sampling_rate)
print("Frequency Domain Representation")
utilities.plot_fd_representation(overlayed_freq_data, overlayed_mag)

overlayed_specgram = utilities.spectrogram(overlayed_samples, overlayed_sampling_rate, max_freq=max(overlayed_freq_data))
print("Spectrogram")
utilities.plot_specgram(overlayed_specgram, overlayed_audio_len, overlayed_sampling_rate)
# Out:
# Time Domain Representation
# Frequency Domain Representation
# Spectrogram

# %% [markdown]
# ## Compare

# %% [markdown]
# ### Time Domain Comparison

# %%
print('Source')
utilities.plot_waveshow_td_representation(src_samples, src_sampling_rate)

print('Noise')
utilities.plot_waveshow_td_representation(noise_samples, noise_sampling_rate)

print('Overlayed')
utilities.plot_waveshow_td_representation(overlayed_samples, overlayed_sampling_rate)
# Out:
# Source
# Noise
# Overlayed

# %% [markdown]
# ### Frequency Domain Comparison

# %%
print('Source')
utilities.plot_fd_representation(src_freq_data, src_mag)

print('Noise')
utilities.plot_fd_representation(noise_freq_data, noise_mag)

print('Overlayed')
utilities.plot_fd_representation(overlayed_freq_data, overlayed_mag)
# Out:
# Source
# Noise
# Overlayed

# %% [markdown]
# ### Spectrogram Comparison

# %%
print('Source')
utilities.plot_specgram(src_specgram, src_audio_len, src_sampling_rate)

print('Noise')
utilities.plot_specgram(nosie_specgram, noise_audio_len, noise_sampling_rate)

print('Overlayed')
utilities.plot_specgram(overlayed_specgram, overlayed_audio_len, overlayed_sampling_rate)
# Out:
# Source
# Noise
# Overlayed
